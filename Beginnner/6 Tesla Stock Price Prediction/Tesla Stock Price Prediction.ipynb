# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("TSLA.csv")
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-05-11  158.102005  164.800003  157.000000  162.257996  162.257996
# 1    2020-05-12  165.399994  168.658005  161.600006  161.882004  161.882004
# 2    2020-05-13  164.166000  165.199997  152.660004  158.192001  158.192001
# 3    2020-05-14  156.000000  160.671997  152.800003  160.666000  160.666000
# 4    2020-05-15  158.070007  161.009995  157.309998  159.834000  159.834000
# ..          ...         ...         ...         ...         ...         ...
# 289  2021-07-02  678.979980  700.000000  673.260010  678.900024  678.900024
# 290  2021-07-06  681.710022  684.000000  651.400024  659.580017  659.580017
# 291  2021-07-07  664.270020  665.700012  638.320007  644.650024  644.650024
# 292  2021-07-08  628.369995  654.429993  620.460022  652.809998  652.809998
# 293  2021-07-09  653.179993  658.909973  644.690002  656.950012  656.950012
#
#        Volume
# 0    82598000
# 1    79534500
# ...

# %%
close = data['Close']
print(close)
ax = close.plot(title='Testla')
ax.figsize=(12, 10)
ax.set_xlabel("Date")
ax.set_ylabel("Stock Prices")
plt.show()
# Out:
# 0      162.257996
# 1      161.882004
# 2      158.192001
# 3      160.666000
# 4      159.834000
#           ...
# 289    678.900024
# 290    659.580017
# 291    644.650024
# 292    652.809998
# 293    656.950012
# Name: Close, Length: 294, dtype: float64

# %%
data["Date"] = pd.to_datetime(data['Date'], infer_datetime_format=True)
data = data[['Date', "Close"]]
